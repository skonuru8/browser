# %%
from browser.browser import Browser

print("Starting Browser")
print("Use Ctrl+S (or Cmd+S) to view browsing history statistics.")

app = Browser()
app.window.mainloop()
# Out:
# Starting Browser
# Use Ctrl+S (or Cmd+S) to view browsing history statistics.
