# %%
# main.ipynb cell 1
from browser import Browser
import tkinter

if __name__ == "__main__":
    app = Browser()
    # You might need to handle the mainloop differently in Jupyter if you want it interactive,
    # but for a Tkinter app popup, just calling the mainloop works.
    app.window.mainloop()
